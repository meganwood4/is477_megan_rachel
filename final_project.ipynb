# %%
import pandas as pd

# %%
df_crimes = pd.read_csv("data/crimes.csv")
df_crimes
# Out:
#               ID Case Number                    Date                 Block  \
# 0       13708839    JJ101083  01/01/2025 11:59:00 PM    009XX N CICERO AVE
# 1       13726091    JJ121235  01/01/2025 11:50:00 PM   035XX W Cortland St
# 2       13709367    JJ101705  01/01/2025 11:47:00 PM     072XX S HOYNE AVE
# 3       13708888    JJ101098  01/01/2025 11:45:00 PM       013XX W 76TH ST
# 4       13708933    JJ101118  01/01/2025 11:39:00 PM        005XX W OAK ST
# ...          ...         ...                     ...                   ...
# 259642  13325219    JH100510  01/01/2024 12:00:00 AM       059XX W LAKE ST
# 259643  13326167    JH101437  01/01/2024 12:00:00 AM   040XX S DREXEL BLVD
# 259644  13325994    JH101383  01/01/2024 12:00:00 AM   036XX S WOLCOTT AVE
# 259645  13325509    JH100882  01/01/2024 12:00:00 AM  082XX S ELIZABETH ST
# 259646  13325146    JH100483  01/01/2024 12:00:00 AM    077XX S LUELLA AVE
#
#         IUCR                Primary Type                          Description  \
# 0       1320             CRIMINAL DAMAGE                           TO VEHICLE
# 1       0710                       THEFT             THEFT FROM MOTOR VEHICLE
# 2       2820               OTHER OFFENSE                     TELEPHONE THREAT
# 3       0430                     BATTERY  AGGRAVATED - OTHER DANGEROUS WEAPON
# 4       1710  OFFENSE INVOLVING CHILDREN   ENDANGERING LIFE / HEALTH OF CHILD
# ...      ...                         ...                                  ...
# 259642  1310             CRIMINAL DAMAGE                          TO PROPERTY
# 259643  1320             CRIMINAL DAMAGE                           TO VEHICLE
# 259644  0820                       THEFT                       $500 AND UNDER
# 259645  1477           WEAPONS VIOLATION           RECKLESS FIREARM DISCHARGE
# 259646  1320             CRIMINAL DAMAGE                           TO VEHICLE
#
#        Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                   CTA BUS    True     False  ...    37              25
# 1                    STREET   False     False  ...    26              22
# 2                 RESIDENCE   False     False  ...    17              67
# 3                 APARTMENT   False     False  ...    17              71
# 4                 APARTMENT   False      True  ...    27               8
# ...                     ...     ...       ...  ...   ...             ...
# 259642            APARTMENT   False      True  ...    29              25
# 259643               STREET   False     False  ...     4              36
# 259644               STREET   False     False  ...    12              59
# 259645            RESIDENCE   False     False  ...    17              71
# 259646               STREET   False     False  ...     7              43
#
#         FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0             14     1144183.0    1906031.0  2025  05/17/2025 03:40:52 PM
# 1             06     1152731.0    1912404.0  2025  11/02/2025 03:41:09 PM
# 2            08A     1163613.0    1856698.0  2025  11/02/2025 03:41:09 PM
# 3            04B     1168743.0    1854387.0  2025  05/17/2025 03:40:52 PM
# 4             20     1172329.0    1907062.0  2025  05/17/2025 03:40:52 PM
# ...          ...           ...          ...   ...                     ...
# 259642        14     1136680.0    1902267.0  2024  12/21/2024 03:40:46 PM
# 259643        14     1182780.0    1878176.0  2024  12/21/2024 03:40:46 PM
# 259644        06     1164283.0    1880493.0  2024  12/21/2024 03:40:46 PM
# 259645        15     1169426.0    1850104.0  2024  12/21/2024 03:40:46 PM
# 259646        14     1192545.0    1854061.0  2024  12/21/2024 03:40:46 PM
#
#          Latitude  Longitude                       Location
# 0       41.898171 -87.745876    (41.89817106, -87.74587608)
# 1       41.915494 -87.714311  (41.915494255, -87.714310832)
# 2       41.762409 -87.675898    (41.7624087, -87.675897826)
# 3       41.755958 -87.657162  (41.755957881, -87.657162192)
# 4       41.900425 -87.642468  (41.900424796, -87.642467932)
# ...           ...        ...                            ...
# 259642  41.887980 -87.773525  (41.887979835, -87.773524594)
# 259643  41.820923 -87.604982  (41.820922725, -87.604981565)
# 259644  41.827691 -87.672772  (41.827691054, -87.672772029)
# 259645  41.744190 -87.654783  (41.744189992, -87.654782936)
# 259646  41.754517 -87.569945  (41.754516844, -87.569944944)
#
# [259647 rows x 22 columns]

# %%
df_crimes["Latitude"].isna().sum()
# Out:
# 1264

# %%
df_crimes.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                      int64
# Community Area            int64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
df_crimes = df_crimes.drop(["Case Number", "Block", "IUCR", "Domestic", "Beat", "District", "Ward", "Community Area", "FBI Code", "X Coordinate", "Y Coordinate"], axis=1)

# %%
df_crimes = df_crimes[(df_crimes["Latitude"].isna() == False) & (df_crimes["Longitude"].isna() == False)]

# %%
df_crimes.dtypes
# Out:
# ID                        int64
# Date                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
df_libraries = pd.read_csv("data/libraries.csv")
df_libraries
# Out:
#                       BRANCH  \
# 0                Albany Park
# 1                    Altgeld
# 2             Archer Heights
# 3                     Austin
# 4              Austin-Irving
# ..                       ...
# 76              West Pullman
# 77                 West Town
# 78     Whitney M. Young, Jr.
# 79  Woodson Regional Library
# 80        Wrightwood-Ashburn
#
#                                         SERVICE HOURS  \
# 0   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 1   Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# 2   Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# 3   Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...
# 4   Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# ..                                                ...
# 76  Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# 77  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 78  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 79    Mon. - Thurs., 9-8; Fri. & Sat., 9-5; Sun., 1-5
# 80  Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
#
#                     ADDRESS     CITY STATE    ZIP           PHONE  \
# 0       3401 W. Foster Ave.  Chicago    IL  60625  (773) 539-5450
# 1          955 E. 131st St.  Chicago    IL  60827  (312) 747-3270
# 2       5055 S. Archer Ave.  Chicago    IL  60632  (312) 747-9241
# 3         5615 W. Race Ave.  Chicago    IL  60644  (312) 746-5038
# 4   6100 W. Irving Park Rd.  Chicago    IL  60634  (312) 744-6222
# ..                      ...      ...   ...    ...             ...
# 76         830 W. 119th St.  Chicago    IL  60643  (312) 747-1425
# 77     1625 W. Chicago Ave.  Chicago    IL  60622  (312) 743-0450
# 78        415 East 79th St.  Chicago    IL  60619  (312) 747-0039
# 79      9525 S. Halsted St.  Chicago    IL  60628  (312) 747-6900
# 80      8530 S. Kedzie Ave.  Chicago    IL  60652  (312) 747-2696
#
#                                     WEBSITE                      BRANCH EMAIL  \
# 0    https://www.chipublib.org/locations/3/          albanypark@chipublib.org
# 1    https://www.chipublib.org/locations/4/             altgeld@chipublib.org
# 2    https://www.chipublib.org/locations/5/       archerheights@chipublib.org
# 3    https://www.chipublib.org/locations/6/              austin@chipublib.org
# 4    https://www.chipublib.org/locations/7/       austin-irving@chipublib.org
# ..                                      ...                               ...
# 76  https://www.chipublib.org/locations/78/         westpullman@chipublib.org
# 77  https://www.chipublib.org/locations/79/            westtown@chipublib.org
# 78  https://www.chipublib.org/locations/80/        whitneyyoung@chipublib.org
# 79  https://www.chipublib.org/locations/81/     woodsonregional@chipublib.org
# 80  https://www.chipublib.org/locations/82/  wrightwood-ashburn@chipublib.org
#
#                                         LOCATION
# 0        (41.97557881655979, -87.71361314512697)
# 1        (41.65719847558056, -87.59883829075173)
# 2        (41.80110836194246, -87.72648385568911)
# 3         (41.88917312206642, -87.7658203582574)
# 4        (41.95312267684315, -87.77928489355646)
# ..                                           ...
# 76        (41.67790647382097, -87.6431683153105)
# 77       (41.89594730478282, -87.66829305460979)
# 78        (41.7510184591363, -87.61495065361933)
# 79      (41.720694885749005, -87.64304817213312)
# 80       (41.73795704970435, -87.70221598421591)
#
# [81 rows x 10 columns]

# %%
df_libraries["LOCATION"].isna().sum()
# Out:
# 0

# %%
df_libraries = df_libraries.drop(["PHONE", "WEBSITE", "BRANCH EMAIL"], axis=1)

# %%
df_libraries[['LATITUDE', 'LONGITUDE']] = (df_libraries['LOCATION'].str.replace('[()]', '', regex=True).str.split(',', expand=True))
df_libraries = df_libraries.assign(LATITUDE=df_libraries['LATITUDE'].astype(float),LONGITUDE=df_libraries['LONGITUDE'].astype(float))

# %%
df_libraries.dtypes
# Out:
# BRANCH            object
# SERVICE HOURS     object
# ADDRESS           object
# CITY              object
# STATE             object
# ZIP                int64
# LOCATION          object
# LATITUDE         float64
# LONGITUDE        float64
# dtype: object

# %%
df_parks = pd.read_csv("data/parks.csv")
df_parks
# Out:
#                                            the_geom OBJECTID_1  \
# 0      POINT (-87.63769762610757 41.76299921150787)          1
# 1      POINT (-87.63792902986378 41.76281652413111)          2
# 2      POINT (-87.63691359952075 41.76084939012162)          3
# 3      POINT (-87.63832013450008 41.76200535623585)          4
# 4      POINT (-87.63805916836576 41.76047384589964)          5
# ...                                             ...        ...
# 4462   POINT (-87.73510131337964 41.80345358991431)      4,507
# 4463  POINT (-87.63766614078884 41.762803879346286)      4,508
# 4464   POINT (-87.75071605094674 41.77673930365681)      4,509
# 4465    POINT (-87.5855355052113 41.78213362866772)      4,510
# 4466   POINT (-87.58535895385735 41.78196370701343)      4,511
#
#                          PARK PARK_NO             FACILITY_N FACILITY_T  \
# 0        HAMILTON (ALEXANDER)       9        CULTURAL CENTER    SPECIAL
# 1        HAMILTON (ALEXANDER)       9              GYMNASIUM     INDOOR
# 2        HAMILTON (ALEXANDER)       9   BASEBALL JR/SOFTBALL    OUTDOOR
# 3        HAMILTON (ALEXANDER)       9   BASEBALL JR/SOFTBALL    OUTDOOR
# 4        HAMILTON (ALEXANDER)       9   BASEBALL JR/SOFTBALL    OUTDOOR
# ...                       ...     ...                    ...        ...
# 4462  ARCHER (WILLIAM BEATTY)     250            TEEN CENTER     INDOOR
# 4463     HAMILTON (ALEXANDER)       9            TEEN CENTER     INDOOR
# 4464         LAWLER (MICHAEL)   1,011  ART TURF - REGULATION    OUTDOOR
# 4465         JACKSON (ANDREW)      19                  TRACK    OUTDOOR
# 4466         JACKSON (ANDREW)      19    ARTIFICIAL TURF REG    OUTDOOR
#
#         X_COORD    Y_COORD GISOBJID
# 0    -87.637698  41.762999    2,494
# 1    -87.637929  41.762817    2,495
# 2    -87.636914  41.760849    2,496
# 3    -87.638320  41.762005    2,497
# 4    -87.638059  41.760474    2,498
# ...         ...        ...      ...
# 4462 -87.735101  41.803454    6,794
# 4463 -87.637666  41.762804    6,793
# 4464 -87.750716  41.776739    6,806
# 4465 -87.585536  41.782134    6,810
# 4466 -87.585359  41.781964    6,809
#
# [4467 rows x 9 columns]

# %%
df_parks = df_parks.drop(["the_geom","GISOBJID"], axis=1)

# %%
df_parks.rename(columns={"X_COORD":"LONGITUDE","Y_COORD":"LATITUDE"}, inplace=True)

# %%
df_parks.dtypes
# Out:
# OBJECTID_1     object
# PARK           object
# PARK_NO        object
# FACILITY_N     object
# FACILITY_T     object
# LONGITUDE     float64
# LATITUDE      float64
# dtype: object

# %%
df_parks["LATITUDE"].isna().sum()
# Out:
# 0

# %%
df_affordable_housing = pd.read_excel("data/affordable_housing.xlsx", nrows=79, header=3)
df_affordable_housing
# Out:
#                Area  Total Units  Total Affordable  Total Legally Restricted  \
# 0       ALBANY PARK       9825.0            3052.0                     340.0
# 1    ARCHER HEIGHTS       1788.0            1028.0                       4.0
# 2     ARMOUR SQUARE       3274.0            2179.0                     874.0
# 3           ASHBURN       2036.0             892.0                      90.0
# 4    AUBURN GRESHAM       9722.0            5798.0                    1181.0
# ..              ...          ...               ...                       ...
# 74       WEST RIDGE      13456.0            3142.0                     595.0
# 75        WEST TOWN      22638.0            4581.0                    1809.0
# 76         WOODLAWN       8019.0            3801.0                    2251.0
# 77              NaN          NaN               NaN                       NaN
# 78  CITY OF CHICAGO     580202.0          209427.0                   59269.0
#
#     Total NOAH  Total Higher Rent  Total No Rent  % Affordable  \
# 0       2712.0             6600.0          173.0      0.310636
# 1       1024.0              681.0           79.0      0.574944
# 2       1305.0              977.0          118.0      0.665547
# 3        802.0             1135.0            9.0      0.438114
# 4       4617.0             3651.0          273.0      0.596379
# ..         ...                ...            ...           ...
# 74      2547.0            10061.0          253.0      0.233502
# 75      2772.0            17396.0          661.0      0.202359
# 76      1550.0             3968.0          250.0      0.473999
# 77         NaN                NaN            NaN           NaN
# 78    150158.0           355738.0        15037.0      0.360955
#
#     % Legally Restricted    % NOAH  ...  Total Legally Restricted.2  \
# 0               0.034606  0.276031  ...                        57.0
# 1               0.002237  0.572707  ...                         2.0
# 2               0.266952  0.398595  ...                       240.0
# 3               0.044204  0.393910  ...                        18.0
# 4               0.121477  0.474902  ...                       299.0
# ..                   ...       ...  ...                         ...
# 74              0.044218  0.189284  ...                       100.0
# 75              0.079910  0.122449  ...                       207.0
# 76              0.280708  0.193291  ...                       812.0
# 77                   NaN       NaN  ...                         NaN
# 78              0.102152  0.258803  ...                     17308.0
#
#     Total NOAH.2  Total Higher Rent.2  Total No Rent.2  Total Units.3  \
# 0         1562.0               2611.0             63.0         2263.0
# 1          563.0                215.0             30.0          770.0
# 2          689.0                309.0             17.0          742.0
# 3          499.0                196.0              0.0         1057.0
# 4         2659.0                855.0             99.0         2927.0
# ..           ...                  ...              ...            ...
# 74        1467.0               3825.0            101.0         3134.0
# 75        1808.0               8770.0            263.0         5243.0
# 76         325.0               1184.0             54.0         2785.0
# 77           NaN                  NaN              NaN            NaN
# 78       76464.0             111495.0           5668.0       136895.0
#
#     Total Affordable.3  Total Legally Restricted.3  Total NOAH.3  \
# 0                446.0                        51.0         395.0
# 1                306.0                         2.0         304.0
# 2                302.0                       114.0         188.0
# 3                194.0                         4.0         190.0
# 4                983.0                       149.0         834.0
# ..                 ...                         ...           ...
# 74               368.0                        22.0         346.0
# 75               986.0                       694.0         292.0
# 76               982.0                       324.0         658.0
# 77                 NaN                         NaN           NaN
# 78             43258.0                     10607.0       32651.0
#
#     Total Higher Rent.3  Total No Rent.3
# 0                1744.0             73.0
# 1                 415.0             49.0
# 2                 339.0            101.0
# 3                 863.0              0.0
# 4                1805.0            139.0
# ..                  ...              ...
# 74               2716.0             50.0
# 75               3929.0            328.0
# 76               1663.0            140.0
# 77                  NaN              NaN
# 78              87642.0           5995.0
#
# [79 rows x 28 columns]

# %%
df_affordable_housing.dtypes
# Out:
# Area                           object
# Total Units                   float64
# Total Affordable              float64
# Total Legally Restricted      float64
# Total NOAH                    float64
# Total Higher Rent             float64
# Total No Rent                 float64
# % Affordable                  float64
# % Legally Restricted          float64
# % NOAH                        float64
# Total Units.1                 float64
# Total Affordable.1            float64
# Total Legally Restricted.1    float64
# Total NOAH.1                  float64
# Total Higher Rent.1           float64
# Total No Rent.1               float64
# Total Units.2                 float64
# Total Affordable.2            float64
# Total Legally Restricted.2    float64
# Total NOAH.2                  float64
# Total Higher Rent.2           float64
# Total No Rent.2               float64
# Total Units.3                 float64
# Total Affordable.3            float64
# Total Legally Restricted.3    float64
# Total NOAH.3                  float64
# Total Higher Rent.3           float64
# Total No Rent.3               float64
# dtype: object

# %%
df_neighborhoods = pd.read_csv("data/neighborhoods.csv")
df_neighborhoods
# Out:
#                                              the_geom           PRI_NEIGH  \
# 0   MULTIPOLYGON (((-87.60670812560372 41.81681377...     Grand Boulevard
# 1   MULTIPOLYGON (((-87.62760697485348 41.87437097...        Printers Row
# 2   MULTIPOLYGON (((-87.66706868914602 41.88885187...       United Center
# 3   MULTIPOLYGON (((-87.65833494805533 41.92166144...  Sheffield & DePaul
# 4   MULTIPOLYGON (((-87.74059567509266 41.88782316...       Humboldt Park
# ..                                                ...                 ...
# 93  MULTIPOLYGON (((-87.74142999502229 41.91698483...      Belmont Cragin
# 94  MULTIPOLYGON (((-87.75619515209075 41.91546954...              Austin
# 95  MULTIPOLYGON (((-87.62645810267597 41.91147052...          Gold Coast
# 96  MULTIPOLYGON (((-87.64878470805166 41.93998753...            Boystown
# 97  MULTIPOLYGON (((-87.63144510787805 41.90390085...         River North
#
#                  SEC_NEIGH       SHAPE_AREA      SHAPE_LEN
# 0              BRONZEVILLE  48,492,503.1554  28,196.837157
# 1             PRINTERS ROW  2,162,137.97139   6,864.247156
# 2            UNITED CENTER  32,520,512.7053  23,101.363745
# 3       SHEFFIELD & DEPAUL  10,482,592.2987  13,227.049745
# 4            HUMBOLDT PARK  125,010,425.593  46,126.751351
# ..                     ...              ...            ...
# 93  BELMONT CRAGIN,HERMOSA  109,099,407.211  43,311.706886
# 94                  AUSTIN  170,037,750.826  55,473.345911
# 95              GOLD COAST  7,165,705.53467  13,685.479377
# 96                BOYSTOWN  3,365,778.97115   9,780.268985
# 97             RIVER NORTH  38,766,442.5194   31,506.03781
#
# [98 rows x 5 columns]

# %%
df_affordable_housing["Area"].unique()
# Out:
# array(['ALBANY PARK', 'ARCHER HEIGHTS', 'ARMOUR SQUARE', 'ASHBURN',
#        'AUBURN GRESHAM', 'AUSTIN', 'AVALON PARK', 'AVONDALE',
#        'BELMONT CRAGIN', 'BEVERLY', 'BRIDGEPORT', 'BRIGHTON PARK',
#        'BURNSIDE', 'CALUMET HEIGHTS', 'CHATHAM', 'CHICAGO LAWN',
#        'CLEARING', 'DOUGLAS', 'DUNNING', 'EAST GARFIELD PARK',
#        'EAST SIDE', 'EDGEWATER', 'EDISON PARK', 'ENGLEWOOD',
#        'FOREST GLEN', 'FULLER PARK', 'GAGE PARK', 'GARFIELD RIDGE',
#        'GRAND BOULEVARD', 'GREATER GRAND CROSSING', 'HEGEWISCH',
#        'HERMOSA', 'HUMBOLDT PARK', 'HYDE PARK', 'IRVING PARK',
#        'JEFFERSON PARK', 'KENWOOD', 'LAKE VIEW', 'LINCOLN PARK',
#        'LINCOLN SQUARE', 'LOGAN SQUARE', 'LOOP', 'LOWER WEST SIDE',
#        'MCKINLEY PARK', 'MONTCLARE', 'MORGAN PARK', 'MOUNT GREENWOOD',
#        'NEAR NORTH SIDE', 'NEAR SOUTH SIDE', 'NEAR WEST SIDE', 'NEW CITY',
#        'NORTH CENTER', 'NORTH LAWNDALE', 'NORTH PARK', 'NORWOOD PARK',
#        'OAKLAND', 'OHARE', 'PORTAGE PARK', 'PULLMAN', 'RIVERDALE',
#        'ROGERS PARK', 'ROSELAND', 'SOUTH CHICAGO', 'SOUTH DEERING',
#        'SOUTH LAWNDALE', 'SOUTH SHORE', 'UPTOWN', 'WASHINGTON HEIGHTS',
#        'WASHINGTON PARK', 'WEST ELSDON', 'WEST ENGLEWOOD',
#        'WEST GARFIELD PARK', 'WEST LAWN', 'WEST PULLMAN', 'WEST RIDGE',
#        'WEST TOWN', 'WOODLAWN', nan, 'CITY OF CHICAGO'], dtype=object)

# %%
df_neighborhoods["PRI_NEIGH"].unique()
# Out:
# array(['Grand Boulevard', 'Printers Row', 'United Center',
#        'Sheffield & DePaul', 'Humboldt Park', 'Garfield Park',
#        'North Lawndale', 'Little Village', 'Armour Square', 'Avalon Park',
#        'Burnside', 'Hermosa', 'Avondale', 'Logan Square',
#        'Calumet Heights', 'East Side', 'West Pullman', 'Garfield Ridge',
#        'New City', 'Englewood', 'Grand Crossing', 'Ashburn',
#        'Mount Greenwood', 'Morgan Park', "O'Hare", 'Jackson Park', 'Loop',
#        'Pullman', 'Riverdale', 'Hegewisch', 'Greektown', 'Douglas',
#        'Museum Campus', 'Edgewater', 'Lake View', 'Lincoln Park',
#        'Magnificent Mile', 'Lincoln Square', 'Oakland', 'Grant Park',
#        'West Loop', 'Fuller Park', 'Andersonville', 'Woodlawn',
#        'Portage Park', 'Rush & Division', 'Little Italy, UIC', 'Kenwood',
#        'Rogers Park', 'Jefferson Park', 'Sauganash,Forest Glen',
#        'North Park', 'Albany Park', 'Irving Park', 'Dunning',
#        'West Ridge', 'Uptown', 'Norwood Park', 'Streeterville',
#        'South Shore', 'Chatham', 'South Chicago', 'Roseland',
#        'North Center', 'South Deering', 'Washington Park',
#        'Millenium Park', 'Near South Side', 'Chinatown', 'Chicago Lawn',
#        'Auburn Gresham', 'Beverly', 'Washington Heights', 'Edison Park',
#        'Hyde Park', 'Bucktown', 'Lower West Side', 'Wrigleyville',
#        'Archer Heights', 'Brighton Park', 'Mckinley Park', 'East Village',
#        'West Town', 'Bridgeport', 'West Elsdon', 'Gage Park', 'Clearing',
#        'West Lawn', 'Wicker Park', 'Ukrainian Village', 'Galewood',
#        'Montclare', 'Old Town', 'Belmont Cragin', 'Austin', 'Gold Coast',
#        'Boystown', 'River North'], dtype=object)

# %%
df_affordable_housing["Area_clean"] = df_affordable_housing["Area"].str.strip().str.upper()
df_neighborhoods["PRI_NEIGH_clean"] = df_neighborhoods["PRI_NEIGH"].str.strip().str.upper()
overlap = set(df_affordable_housing["Area_clean"]) & set(df_neighborhoods["PRI_NEIGH_clean"])
df_affordable_housing = df_affordable_housing[df_affordable_housing["Area_clean"].isin(overlap)].copy()
df_neighborhoods = df_neighborhoods[df_neighborhoods["PRI_NEIGH_clean"].isin(overlap)].copy()

# %%
len(df_affordable_housing["Area"].unique())
# Out:
# 68

# %%
len(df_neighborhoods["PRI_NEIGH"].unique())
# Out:
# 68

# %%
import geopandas as gpd
from shapely import wkt

# %%
df_neighborhoods["geometry"] = df_neighborhoods["the_geom"].apply(wkt.loads)
gdf_neighborhoods = gpd.GeoDataFrame(df_neighborhoods, geometry="geometry", crs="EPSG:4326")

# %%
gdf_crimes = gpd.GeoDataFrame(df_crimes, geometry=gpd.points_from_xy(df_crimes.Longitude, df_crimes.Latitude), crs="EPSG:4326")

# %%
gdf_libraries = gpd.GeoDataFrame(df_libraries, geometry=gpd.points_from_xy(df_libraries.LONGITUDE, df_libraries.LATITUDE), crs="EPSG:4326")

# %%
gdf_parks = gpd.GeoDataFrame(df_parks, geometry=gpd.points_from_xy(df_parks.LONGITUDE, df_parks.LATITUDE), crs="EPSG:4326")

# %%
gdf_crimes = gpd.sjoin(gdf_crimes, gdf_neighborhoods[["PRI_NEIGH", "geometry"]], how="left", predicate="within")

# %%
gdf_crimes = gdf_crimes[gdf_crimes["PRI_NEIGH"].isna() == False]

# %%
gdf_crimes
# Out:
#               ID                    Date       Primary Type  \
# 0       13708839  01/01/2025 11:59:00 PM    CRIMINAL DAMAGE
# 1       13726091  01/01/2025 11:50:00 PM              THEFT
# 2       13709367  01/01/2025 11:47:00 PM      OTHER OFFENSE
# 3       13708888  01/01/2025 11:45:00 PM            BATTERY
# 5       13708883  01/01/2025 11:35:00 PM            BATTERY
# ...          ...                     ...                ...
# 259642  13325219  01/01/2024 12:00:00 AM    CRIMINAL DAMAGE
# 259643  13326167  01/01/2024 12:00:00 AM    CRIMINAL DAMAGE
# 259644  13325994  01/01/2024 12:00:00 AM              THEFT
# 259645  13325509  01/01/2024 12:00:00 AM  WEAPONS VIOLATION
# 259646  13325146  01/01/2024 12:00:00 AM    CRIMINAL DAMAGE
#
#                                 Description Location Description  Arrest  \
# 0                                TO VEHICLE              CTA BUS    True
# 1                  THEFT FROM MOTOR VEHICLE               STREET   False
# 2                          TELEPHONE THREAT            RESIDENCE   False
# 3       AGGRAVATED - OTHER DANGEROUS WEAPON            APARTMENT   False
# 5       AGGRAVATED - OTHER DANGEROUS WEAPON               STREET   False
# ...                                     ...                  ...     ...
# 259642                          TO PROPERTY            APARTMENT   False
# 259643                           TO VEHICLE               STREET   False
# 259644                       $500 AND UNDER               STREET   False
# 259645           RECKLESS FIREARM DISCHARGE            RESIDENCE   False
# 259646                           TO VEHICLE               STREET   False
#
#         Year              Updated On   Latitude  Longitude  \
# 0       2025  05/17/2025 03:40:52 PM  41.898171 -87.745876
# 1       2025  11/02/2025 03:41:09 PM  41.915494 -87.714311
# 2       2025  11/02/2025 03:41:09 PM  41.762409 -87.675898
# 3       2025  05/17/2025 03:40:52 PM  41.755958 -87.657162
# 5       2025  11/02/2025 03:41:09 PM  41.752940 -87.578459
# ...      ...                     ...        ...        ...
# 259642  2024  12/21/2024 03:40:46 PM  41.887980 -87.773525
# 259643  2024  12/21/2024 03:40:46 PM  41.820923 -87.604982
# 259644  2024  12/21/2024 03:40:46 PM  41.827691 -87.672772
# 259645  2024  12/21/2024 03:40:46 PM  41.744190 -87.654783
# 259646  2024  12/21/2024 03:40:46 PM  41.754517 -87.569945
#
#                              Location                    geometry  \
# 0         (41.89817106, -87.74587608)  POINT (-87.74588 41.89817)
# 1       (41.915494255, -87.714310832)  POINT (-87.71431 41.91549)
# 2         (41.7624087, -87.675897826)   POINT (-87.6759 41.76241)
# 3       (41.755957881, -87.657162192)  POINT (-87.65716 41.75596)
# 5       (41.752940239, -87.578458689)  POINT (-87.57846 41.75294)
# ...                               ...                         ...
# 259642  (41.887979835, -87.773524594)  POINT (-87.77352 41.88798)
# 259643  (41.820922725, -87.604981565)  POINT (-87.60498 41.82092)
# 259644  (41.827691054, -87.672772029)  POINT (-87.67277 41.82769)
# 259645  (41.744189992, -87.654782936)  POINT (-87.65478 41.74419)
# 259646  (41.754516844, -87.569944944)  POINT (-87.56994 41.75452)
#
#         index_right       PRI_NEIGH
# 0              94.0          Austin
# 1              13.0    Logan Square
# 2              19.0       Englewood
# 3              70.0  Auburn Gresham
# 5              59.0     South Shore
# ...             ...             ...
# 259642         94.0          Austin
# 259643         38.0         Oakland
# 259644         80.0   Mckinley Park
# 259645         70.0  Auburn Gresham
# 259646         59.0     South Shore
#
# [203931 rows x 14 columns]

# %%
gdf_libraries = gpd.sjoin(gdf_libraries, gdf_neighborhoods[["PRI_NEIGH", "geometry"]], how="left", predicate="within")

# %%
gdf_libraries = gdf_libraries[gdf_libraries["PRI_NEIGH"].isna() == False]

# %%
gdf_libraries
# Out:
#                       BRANCH  \
# 0                Albany Park
# 1                    Altgeld
# 2             Archer Heights
# 3                     Austin
# 4              Austin-Irving
# ..                       ...
# 76              West Pullman
# 77                 West Town
# 78     Whitney M. Young, Jr.
# 79  Woodson Regional Library
# 80        Wrightwood-Ashburn
#
#                                         SERVICE HOURS  \
# 0   Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 1   Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# 2   Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# 3   Mon. & Wed., Noon-8; Tues. & Thurs., 10-6; Fri...
# 4   Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# ..                                                ...
# 76  Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
# 77  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 78  Mon. & Wed., 10-6; Tues. & Thurs., Noon-8; Fri...
# 79    Mon. - Thurs., 9-8; Fri. & Sat., 9-5; Sun., 1-5
# 80  Mon. & Wed., Noon-8; Tue. & Thu., 10-6; Fri. &...
#
#                     ADDRESS     CITY STATE    ZIP  \
# 0       3401 W. Foster Ave.  Chicago    IL  60625
# 1          955 E. 131st St.  Chicago    IL  60827
# 2       5055 S. Archer Ave.  Chicago    IL  60632
# 3         5615 W. Race Ave.  Chicago    IL  60644
# 4   6100 W. Irving Park Rd.  Chicago    IL  60634
# ..                      ...      ...   ...    ...
# 76         830 W. 119th St.  Chicago    IL  60643
# 77     1625 W. Chicago Ave.  Chicago    IL  60622
# 78        415 East 79th St.  Chicago    IL  60619
# 79      9525 S. Halsted St.  Chicago    IL  60628
# 80      8530 S. Kedzie Ave.  Chicago    IL  60652
#
#                                         LOCATION   LATITUDE  LONGITUDE  \
# 0        (41.97557881655979, -87.71361314512697)  41.975579 -87.713613
# 1        (41.65719847558056, -87.59883829075173)  41.657198 -87.598838
# 2        (41.80110836194246, -87.72648385568911)  41.801108 -87.726484
# 3         (41.88917312206642, -87.7658203582574)  41.889173 -87.765820
# 4        (41.95312267684315, -87.77928489355646)  41.953123 -87.779285
# ..                                           ...        ...        ...
# 76        (41.67790647382097, -87.6431683153105)  41.677906 -87.643168
# 77       (41.89594730478282, -87.66829305460979)  41.895947 -87.668293
# 78        (41.7510184591363, -87.61495065361933)  41.751018 -87.614951
# 79      (41.720694885749005, -87.64304817213312)  41.720695 -87.643048
# 80       (41.73795704970435, -87.70221598421591)  41.737957 -87.702216
#
#                       geometry  index_right           PRI_NEIGH
# 0   POINT (-87.71361 41.97558)         51.0          North Park
# 1    POINT (-87.59884 41.6572)         28.0           Riverdale
# 2   POINT (-87.72648 41.80111)         78.0      Archer Heights
# 3   POINT (-87.76582 41.88917)         94.0              Austin
# 4   POINT (-87.77928 41.95312)         44.0        Portage Park
# ..                         ...          ...                 ...
# 76  POINT (-87.64317 41.67791)         16.0        West Pullman
# 77  POINT (-87.66829 41.89595)         82.0           West Town
# 78  POINT (-87.61495 41.75102)         60.0             Chatham
# 79  POINT (-87.64305 41.72069)         72.0  Washington Heights
# 80  POINT (-87.70222 41.73796)         21.0             Ashburn
#
# [67 rows x 12 columns]

# %%
gdf_parks = gpd.sjoin(gdf_parks, gdf_neighborhoods[["PRI_NEIGH", "geometry"]], how="left", predicate="within")

# %%
gdf_parks = gdf_parks[gdf_parks["PRI_NEIGH"].isna() == False]

# %%
gdf_parks
# Out:
#      OBJECTID_1                     PARK PARK_NO             FACILITY_N  \
# 0             1     HAMILTON (ALEXANDER)       9        CULTURAL CENTER
# 1             2     HAMILTON (ALEXANDER)       9              GYMNASIUM
# 2             3     HAMILTON (ALEXANDER)       9   BASEBALL JR/SOFTBALL
# 3             4     HAMILTON (ALEXANDER)       9   BASEBALL JR/SOFTBALL
# 4             5     HAMILTON (ALEXANDER)       9   BASEBALL JR/SOFTBALL
# ...         ...                      ...     ...                    ...
# 4460      4,505       ROBICHAUX (JOSEPH)     320            TEEN CENTER
# 4461      4,506     KENNICOTT (JONATHAN)     485            TEEN CENTER
# 4462      4,507  ARCHER (WILLIAM BEATTY)     250            TEEN CENTER
# 4463      4,508     HAMILTON (ALEXANDER)       9            TEEN CENTER
# 4464      4,509         LAWLER (MICHAEL)   1,011  ART TURF - REGULATION
#
#      FACILITY_T  LONGITUDE   LATITUDE                    geometry  \
# 0       SPECIAL -87.637698  41.762999     POINT (-87.6377 41.763)
# 1        INDOOR -87.637929  41.762817  POINT (-87.63793 41.76282)
# 2       OUTDOOR -87.636914  41.760849  POINT (-87.63691 41.76085)
# 3       OUTDOOR -87.638320  41.762005  POINT (-87.63832 41.76201)
# 4       OUTDOOR -87.638059  41.760474  POINT (-87.63806 41.76047)
# ...         ...        ...        ...                         ...
# 4460     INDOOR -87.634397  41.725534   POINT (-87.6344 41.72553)
# 4461     INDOOR -87.597709  41.814372  POINT (-87.59771 41.81437)
# 4462     INDOOR -87.735101  41.803454   POINT (-87.7351 41.80345)
# 4463     INDOOR -87.637666  41.762804   POINT (-87.63767 41.7628)
# 4464    OUTDOOR -87.750716  41.776739  POINT (-87.75072 41.77674)
#
#       index_right           PRI_NEIGH
# 0            19.0           Englewood
# 1            19.0           Englewood
# 2            19.0           Englewood
# 3            19.0           Englewood
# 4            19.0           Englewood
# ...           ...                 ...
# 4460         72.0  Washington Heights
# 4461         47.0             Kenwood
# 4462         78.0      Archer Heights
# 4463         19.0           Englewood
# 4464         86.0            Clearing
#
# [3788 rows x 10 columns]

# %%
unique_parks = gdf_parks[['PARK', 'PRI_NEIGH']].drop_duplicates()

# %%
parks_per_neighborhood = unique_parks.groupby("PRI_NEIGH").size().reset_index(name="num_parks")

# %%
parks_per_neighborhood
# Out:
#          PRI_NEIGH  num_parks
# 0      Albany Park          7
# 1   Archer Heights          4
# 2    Armour Square          2
# 3          Ashburn          7
# 4   Auburn Gresham          8
# ..             ...        ...
# 63       West Lawn          3
# 64    West Pullman          7
# 65      West Ridge         11
# 66       West Town          5
# 67        Woodlawn          8
#
# [68 rows x 2 columns]

# %%
unique_libraries = gdf_libraries[['BRANCH', 'PRI_NEIGH']].drop_duplicates()

# %%
libraries_per_neighborhood = unique_libraries.groupby("PRI_NEIGH").size().reset_index(name="num_libraries")

# %%
libraries_per_neighborhood
# Out:
#              PRI_NEIGH  num_libraries
# 0          Albany Park              1
# 1       Archer Heights              1
# 2              Ashburn              2
# 3       Auburn Gresham              2
# 4               Austin              3
# 5          Avalon Park              1
# 6       Belmont Cragin              1
# 7              Beverly              1
# 8           Bridgeport              1
# 9        Brighton Park              1
# 10             Chatham              1
# 11        Chicago Lawn              1
# 12            Clearing              1
# 13             Douglas              2
# 14             Dunning              1
# 15           Edgewater              1
# 16           Englewood              2
# 17           Gage Park              1
# 18      Garfield Ridge              1
# 19     Grand Boulevard              1
# 20           Hegewisch              1
# 21       Humboldt Park              3
# 22         Irving Park              1
# 23             Kenwood              1
# 24           Lake View              1
# 25      Lincoln Square              1
# 26        Logan Square              1
# 27                Loop              1
# 28     Lower West Side              1
# 29       Mckinley Park              1
# 30           Montclare              1
# 31         Morgan Park              1
# 32     Mount Greenwood              1
# 33            New City              3
# 34      North Lawndale              1
# 35          North Park              1
# 36        Norwood Park              2
# 37        Portage Park              3
# 38           Riverdale              1
# 39         Rogers Park              1
# 40            Roseland              2
# 41       South Chicago              1
# 42       South Deering              1
# 43         South Shore              1
# 44              Uptown              2
# 45  Washington Heights              1
# 46           West Lawn              1
# 47        West Pullman              1
# 48          West Ridge              2
# 49           West Town              1
# 50            Woodlawn              1

# %%
crime_counts = (gdf_crimes.groupby(['PRI_NEIGH', 'Primary Type']).size().reset_index(name='count'))
crime_counts
# Out:
#         PRI_NEIGH                       Primary Type  count
# 0     Albany Park                              ARSON      3
# 1     Albany Park                            ASSAULT    200
# 2     Albany Park                            BATTERY    477
# 3     Albany Park                           BURGLARY    106
# 4     Albany Park  CONCEALED CARRY LICENSE VIOLATION      2
# ...           ...                                ...    ...
# 1564     Woodlawn                            ROBBERY    113
# 1565     Woodlawn                        SEX OFFENSE     11
# 1566     Woodlawn                           STALKING      4
# 1567     Woodlawn                              THEFT    682
# 1568     Woodlawn                  WEAPONS VIOLATION    213
#
# [1569 rows x 3 columns]

# %%
crime_totals = (crime_counts.groupby("PRI_NEIGH")["count"].sum().reset_index(name="total_crimes"))
crime_totals
# Out:
#          PRI_NEIGH  total_crimes
# 0      Albany Park          2461
# 1   Archer Heights          1119
# 2    Armour Square           533
# 3          Ashburn          2381
# 4   Auburn Gresham          6644
# ..             ...           ...
# 63       West Lawn          1935
# 64    West Pullman          3692
# 65      West Ridge          3652
# 66       West Town          3005
# 67        Woodlawn          3752
#
# [68 rows x 2 columns]

# %%
crime_types = (crime_counts.pivot(index="PRI_NEIGH", columns="Primary Type", values="count").fillna(0).reset_index())
crime_types
# Out:
# Primary Type       PRI_NEIGH  ARSON  ASSAULT  BATTERY  BURGLARY  \
# 0                Albany Park    3.0    200.0    477.0     106.0
# 1             Archer Heights    3.0     95.0    158.0      46.0
# 2              Armour Square    1.0     45.0    115.0      16.0
# 3                    Ashburn    6.0    229.0    366.0      90.0
# 4             Auburn Gresham   12.0    766.0   1367.0     209.0
# ..                       ...    ...      ...      ...       ...
# 63                 West Lawn    4.0    142.0    294.0      72.0
# 64              West Pullman   16.0    414.0    675.0     108.0
# 65                West Ridge    5.0    291.0    634.0     119.0
# 66                 West Town    2.0    162.0    297.0     191.0
# 67                  Woodlawn    7.0    411.0    825.0     131.0
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIMINAL DAMAGE  \
# 0                                           2.0            311.0
# 1                                           0.0             86.0
# 2                                           0.0             59.0
# 3                                           0.0            296.0
# 4                                           2.0            987.0
# ..                                          ...              ...
# 63                                          0.0            234.0
# 64                                          2.0            564.0
# 65                                          1.0            469.0
# 66                                          1.0            405.0
# 67                                          2.0            455.0
#
# Primary Type  CRIMINAL SEXUAL ASSAULT  CRIMINAL TRESPASS  DECEPTIVE PRACTICE  \
# 0                                19.0               55.0               161.0
# 1                                 7.0               13.0                70.0
# 2                                 0.0                6.0                32.0
# 3                                10.0               35.0               161.0
# 4                                24.0              113.0               268.0
# ..                                ...                ...                 ...
# 63                               11.0               17.0               114.0
# 64                               18.0               52.0               196.0
# 65                               20.0               59.0               342.0
# 66                                8.0               54.0               173.0
# 67                               18.0               84.0               140.0
#
# Primary Type  ...  OTHER NARCOTIC VIOLATION  OTHER OFFENSE  PROSTITUTION  \
# 0             ...                       0.0          182.0           2.0
# 1             ...                       0.0           70.0           0.0
# 2             ...                       0.0           29.0           1.0
# 3             ...                       0.0          200.0           0.0
# 4             ...                       0.0          612.0           0.0
# ..            ...                       ...            ...           ...
# 63            ...                       0.0          152.0           0.0
# 64            ...                       0.0          323.0           0.0
# 65            ...                       0.0          239.0           0.0
# 66            ...                       0.0           98.0           0.0
# 67            ...                       0.0          256.0           0.0
#
# Primary Type  PUBLIC INDECENCY  PUBLIC PEACE VIOLATION  ROBBERY  SEX OFFENSE  \
# 0                          0.0                     6.0     72.0         19.0
# 1                          0.0                     5.0     39.0          3.0
# 2                          0.0                     9.0     38.0          0.0
# 3                          0.0                     4.0     49.0         12.0
# 4                          1.0                    22.0    231.0         31.0
# ..                         ...                     ...      ...          ...
# 63                         0.0                     9.0     43.0         15.0
# 64                         0.0                    12.0    107.0         11.0
# 65                         0.0                     7.0    119.0         31.0
# 66                         0.0                    12.0    129.0          7.0
# 67                         0.0                     5.0    113.0         11.0
#
# Primary Type  STALKING  THEFT  WEAPONS VIOLATION
# 0                  3.0  600.0               28.0
# 1                  0.0  354.0               35.0
# 2                  0.0  116.0               12.0
# 3                  7.0  425.0               57.0
# 4                 24.0  900.0              264.0
# ..                 ...    ...                ...
# 63                 2.0  475.0               44.0
# 64                 6.0  544.0              183.0
# 65                10.0  824.0               26.0
# 66                 4.0  974.0               17.0
# 67                 4.0  682.0              213.0
#
# [68 rows x 32 columns]

# %%
df_affordable_housing = df_affordable_housing[(df_affordable_housing["Area"].notna()) & (df_affordable_housing["Area"] != "CITY OF CHICAGO")]
df_affordable_housing["PRI_NEIGH"] = df_affordable_housing["Area"].str.strip().str.title()

df_affordable_housing = df_affordable_housing[[
    "PRI_NEIGH",
    "Total Units",
    "Total Affordable",
    "% Affordable"
]].copy()

# %%
df_affordable_housing
# Out:
#          PRI_NEIGH  Total Units  Total Affordable  % Affordable
# 0      Albany Park       9825.0            3052.0      0.310636
# 1   Archer Heights       1788.0            1028.0      0.574944
# 2    Armour Square       3274.0            2179.0      0.665547
# 3          Ashburn       2036.0             892.0      0.438114
# 4   Auburn Gresham       9722.0            5798.0      0.596379
# ..             ...          ...               ...           ...
# 72       West Lawn       2613.0            1190.0      0.455415
# 73    West Pullman       3772.0            1871.0      0.496023
# 74      West Ridge      13456.0            3142.0      0.233502
# 75       West Town      22638.0            4581.0      0.202359
# 76        Woodlawn       8019.0            3801.0      0.473999
#
# [68 rows x 4 columns]

# %%
gdf_neighborhood_final = (
    gdf_neighborhoods[["PRI_NEIGH", "geometry"]]
    .merge(parks_per_neighborhood, on="PRI_NEIGH", how="left")
    .merge(libraries_per_neighborhood, on="PRI_NEIGH", how="left")
    .merge(df_affordable_housing, on="PRI_NEIGH", how="left")
    .merge(crime_totals, on="PRI_NEIGH", how="left")
    .merge(crime_types, on="PRI_NEIGH", how="left")
)

df_neighborhood_final = gdf_neighborhood_final.drop(columns="geometry")

# %%
gdf_neighborhood_final
# Out:
#           PRI_NEIGH                                           geometry  \
# 0   Grand Boulevard  MULTIPOLYGON (((-87.60671 41.81681, -87.6067 4...
# 1     Humboldt Park  MULTIPOLYGON (((-87.7406 41.88782, -87.7406 41...
# 2    North Lawndale  MULTIPOLYGON (((-87.72024 41.86987, -87.71965 ...
# 3     Armour Square  MULTIPOLYGON (((-87.6292 41.84713, -87.62919 4...
# 4       Avalon Park  MULTIPOLYGON (((-87.58566 41.7515, -87.58475 4...
# ..              ...                                                ...
# 63         Clearing  MULTIPOLYGON (((-87.73762 41.78578, -87.73761 ...
# 64        West Lawn  MULTIPOLYGON (((-87.71255 41.75734, -87.71278 ...
# 65        Montclare  MULTIPOLYGON (((-87.78871 41.91721, -87.78873 ...
# 66   Belmont Cragin  MULTIPOLYGON (((-87.74143 41.91698, -87.74141 ...
# 67           Austin  MULTIPOLYGON (((-87.7562 41.91547, -87.75588 4...
#
#     num_parks  num_libraries  Total Units  Total Affordable  % Affordable  \
# 0          14            1.0       7914.0            4123.0      0.520975
# 1          17            3.0      10854.0            5099.0      0.469781
# 2          14            1.0       8382.0            4717.0      0.562754
# 3           2            NaN       3274.0            2179.0      0.665547
# 4           2            1.0       1324.0             564.0      0.425982
# ..        ...            ...          ...               ...           ...
# 63          4            1.0       2790.0            1080.0      0.387097
# 64          3            1.0       2613.0            1190.0      0.455415
# 65          2            1.0       1702.0             686.0      0.403055
# 66          4            1.0      10911.0            4756.0      0.435890
# 67         15            3.0      18880.0            9558.0      0.506250
#
#     total_crimes  ARSON  ASSAULT  ...  OTHER NARCOTIC VIOLATION  \
# 0           3725    3.0    362.0  ...                       0.0
# 1           8467   22.0    750.0  ...                       0.0
# 2           6511   18.0    739.0  ...                       0.0
# 3            533    1.0     45.0  ...                       0.0
# 4           1035    1.0    120.0  ...                       0.0
# ..           ...    ...      ...  ...                       ...
# 63          1093    5.0    116.0  ...                       0.0
# 64          1935    4.0    142.0  ...                       0.0
# 65           614    0.0     56.0  ...                       0.0
# 66          4847    7.0    475.0  ...                       0.0
# 67         12284   28.0   1285.0  ...                       0.0
#
#     OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  PUBLIC PEACE VIOLATION  \
# 0           245.0           0.0               0.0                    14.0
# 1           576.0           7.0               0.0                    40.0
# 2           421.0          18.0               0.0                    28.0
# 3            29.0           1.0               0.0                     9.0
# 4            76.0           0.0               0.0                     1.0
# ..            ...           ...               ...                     ...
# 63          112.0           1.0               0.0                     1.0
# 64          152.0           0.0               0.0                     9.0
# 65           46.0           0.0               0.0                     1.0
# 66          466.0           3.0               0.0                    10.0
# 67          805.0         107.0               0.0                    48.0
#
#     ROBBERY  SEX OFFENSE  STALKING   THEFT  WEAPONS VIOLATION
# 0      83.0         14.0      12.0   769.0              149.0
# 1     396.0         43.0      18.0  1224.0              306.0
# 2     305.0         26.0      10.0   809.0              278.0
# 3      38.0          0.0       0.0   116.0               12.0
# 4      32.0          4.0       3.0   193.0               43.0
# ..      ...          ...       ...     ...                ...
# 63     19.0          3.0       6.0   176.0               18.0
# 64     43.0         15.0       2.0   475.0               44.0
# 65     14.0          1.0       1.0   126.0                9.0
# 66    165.0         41.0      24.0  1144.0              116.0
# 67    611.0         47.0      10.0  1927.0              482.0
#
# [68 rows x 39 columns]

# %%
df_neighborhood_final
# Out:
#           PRI_NEIGH  num_parks  num_libraries  Total Units  Total Affordable  \
# 0   Grand Boulevard         14            1.0       7914.0            4123.0
# 1     Humboldt Park         17            3.0      10854.0            5099.0
# 2    North Lawndale         14            1.0       8382.0            4717.0
# 3     Armour Square          2            NaN       3274.0            2179.0
# 4       Avalon Park          2            1.0       1324.0             564.0
# ..              ...        ...            ...          ...               ...
# 63         Clearing          4            1.0       2790.0            1080.0
# 64        West Lawn          3            1.0       2613.0            1190.0
# 65        Montclare          2            1.0       1702.0             686.0
# 66   Belmont Cragin          4            1.0      10911.0            4756.0
# 67           Austin         15            3.0      18880.0            9558.0
#
#     % Affordable  total_crimes  ARSON  ASSAULT  BATTERY  ...  \
# 0       0.520975          3725    3.0    362.0    673.0  ...
# 1       0.469781          8467   22.0    750.0   1547.0  ...
# 2       0.562754          6511   18.0    739.0   1586.0  ...
# 3       0.665547           533    1.0     45.0    115.0  ...
# 4       0.425982          1035    1.0    120.0    179.0  ...
# ..           ...           ...    ...      ...      ...  ...
# 63      0.387097          1093    5.0    116.0    194.0  ...
# 64      0.455415          1935    4.0    142.0    294.0  ...
# 65      0.403055           614    0.0     56.0     99.0  ...
# 66      0.435890          4847    7.0    475.0    893.0  ...
# 67      0.506250         12284   28.0   1285.0   2741.0  ...
#
#     OTHER NARCOTIC VIOLATION  OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# 0                        0.0          245.0           0.0               0.0
# 1                        0.0          576.0           7.0               0.0
# 2                        0.0          421.0          18.0               0.0
# 3                        0.0           29.0           1.0               0.0
# 4                        0.0           76.0           0.0               0.0
# ..                       ...            ...           ...               ...
# 63                       0.0          112.0           1.0               0.0
# 64                       0.0          152.0           0.0               0.0
# 65                       0.0           46.0           0.0               0.0
# 66                       0.0          466.0           3.0               0.0
# 67                       0.0          805.0         107.0               0.0
#
#     PUBLIC PEACE VIOLATION  ROBBERY  SEX OFFENSE  STALKING   THEFT  \
# 0                     14.0     83.0         14.0      12.0   769.0
# 1                     40.0    396.0         43.0      18.0  1224.0
# 2                     28.0    305.0         26.0      10.0   809.0
# 3                      9.0     38.0          0.0       0.0   116.0
# 4                      1.0     32.0          4.0       3.0   193.0
# ..                     ...      ...          ...       ...     ...
# 63                     1.0     19.0          3.0       6.0   176.0
# 64                     9.0     43.0         15.0       2.0   475.0
# 65                     1.0     14.0          1.0       1.0   126.0
# 66                    10.0    165.0         41.0      24.0  1144.0
# 67                    48.0    611.0         47.0      10.0  1927.0
#
#     WEAPONS VIOLATION
# 0               149.0
# 1               306.0
# 2               278.0
# 3                12.0
# 4                43.0
# ..                ...
# 63               18.0
# 64               44.0
# 65                9.0
# 66              116.0
# 67              482.0
#
# [68 rows x 38 columns]

# %%
import matplotlib.pyplot as plt

gdf_neighborhood_final.plot(
    column="total_crimes",
    legend=True
)
plt.title("Total Crimes by Chicago Neighborhood")
plt.savefig("graphs/total_crimes_by_neighborhood.png")
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
plt.scatter(df_neighborhood_final["num_parks"],df_neighborhood_final["total_crimes"])
plt.xlabel("Number of Parks")
plt.ylabel("Total Crimes")
plt.title("Parks vs. Crime by Neighborhood")
plt.grid(True)
plt.savefig("graphs/parks_vs_crime_by_neighborhood.png")
plt.close()

# %%
plt.scatter(df_neighborhood_final["num_libraries"], df_neighborhood_final["total_crimes"])
plt.xlabel("Number of Libraries")
plt.ylabel("Total Crimes")
plt.title("Libraries vs. Crime by Neighborhood")
plt.grid(True)
plt.savefig("graphs/libraries_vs_crime_by_neighborhood.png")
plt.close()

# %%
plt.scatter(df_neighborhood_final["% Affordable"], df_neighborhood_final["total_crimes"])
plt.xlabel("Percent of Affordable Housing")
plt.ylabel("Total Crimes")
plt.title("% Affordable Housing vs. Crime by Neighborhood")
plt.grid(True)
plt.savefig("graphs/percent_affordable_vs_crime_by_neighborhood.png")
plt.close()

# %%
plt.scatter(df_neighborhood_final["Total Affordable"], df_neighborhood_final["total_crimes"])
plt.xlabel("Total Affordable Housing Units")
plt.ylabel("Total Crimes")
plt.title("Total Affordable Units vs. Crime by Neighborhood")
plt.grid(True)
plt.savefig("graphs/units_affordable_vs_crime_by_neighborhood.png")
plt.close()
